# %% [markdown]
# # Validating Strawberry Puree via Infrared Spectral Analysis
#
# <br>
# <br>
#
# The purpose of this analysis is to classify strawberry puree as "pure" or "not-pure" by analyzing the frequency domain in the mid-infrared spectrum using Attenuated Total Reflectance sampling.  Not-pure samples have been adulterated with other fruit purees.
#
# Spectral analysis is a common practice in analyzing fruit and vegetables.  Here, we use a back prop network with 5 hidden layers.
#
# <br>
# <br>
#
# ~~The Input Layer is made up of 235 nodes.  Each input node represents the strength of a specific wavenumber~~
#
# ~~Hidden Layers 1 and 5 have 1000 ReLU nodes~~
#
# ~~Hidden Layers 2,3 and 4 have 10000~~
#
# ~~The Output Layer is made up of 2 nodes representing unadulerated strawberry puree or the adulterated version.~~
#
# <br>
# <br>
# <br>
#
# The data used in this notebook came from an original analysis by Holland, Kemsley and Wilson.
#
# <i>"Use of Fourier transform infrared spectroscopy and partial least squares regression for the detection of adulteration of strawberry purees" Holland JK, Kemsley EK, Wilson RH. (1998). Journal of the Science of Food and Agriculture, 76, 263-269</i>
#
# Abstract and Full-text (paywall) are available here: https://europepmc.org/article/agr/ind21806286
#
# The dataset was downloaded from: http://www.timeseriesclassification.com/description.php?Dataset=Strawberry
#
# <br>
# <br>
# <br>

# %% [markdown]
# ## Side note:
#
# I deliberately threw the bus at the problem.  There is no need  for so many dense layers.  There is no need to 80 epochs of training.  This was just a feasibility study and needs to be cleaned up.
#
# <br>
# <br>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas_profiling import ProfileReport
# %matplotlib inline

# set sensible default parameters for matplotlib
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100

plt.style.use('dark_background')

# %%
import torch
print('CUDA available: '.ljust(25), torch.cuda.is_available())
print('CUDA device count: '.ljust(25), torch.cuda.device_count())

current_device = torch.cuda.current_device()
print('Current CUDA Device num: '.ljust(25), current_device)
# torch.cuda.device(current_device)
print('Current CUDA Device: '.ljust(25), torch.cuda.get_device_name(current_device))
# Out:
# CUDA available:           True
# CUDA device count:        1
# Current CUDA Device num:  0
# Current CUDA Device:      GeForce RTX 2070 SUPER

# %%
import tensorflow as tf
tf.config.experimental.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
df = pd.read_csv('MIR_Fruit_purees.csv')
df.head()
# Out:
#    Wavenumbers  NON-Strawberry  NON-Strawberry.1  NON-Strawberry.2  \
# 0      899.327        0.002806          0.002637          0.002416
# 1      903.187        0.002732          0.002638          0.002480
# 2      907.047        0.002661          0.002651          0.002511
# 3      910.907        0.002657          0.002757          0.002611
# 4      914.767        0.002699          0.003000          0.002802
#
#    NON-Strawberry.3  NON-Strawberry.4  NON-Strawberry.5  NON-Strawberry.6  \
# 0          0.002345          0.002303          0.002514          0.002105
# 1          0.002292          0.002342          0.002488          0.002078
# 2          0.002249          0.002350          0.002477          0.002077
# 3          0.002303          0.002419          0.002542          0.002154
# 4          0.002466          0.002561          0.002713          0.002311
#
#    NON-Strawberry.7  NON-Strawberry.8  ...  NON-Strawberry.622  \
# 0          0.002018          0.002154  ...            0.002539
# 1          0.001999          0.002165  ...            0.002507
# 2          0.001945          0.002191  ...            0.002483
# 3          0.001964          0.002275  ...            0.002563
# 4          0.002083          0.002470  ...            0.002764
#
#    NON-Strawberry.623  NON-Strawberry.624  NON-Strawberry.625  \
# 0            0.002569            0.002723            0.002542
# 1            0.002569            0.002714            0.002539
# 2            0.002541            0.002740            0.002574
# 3            0.002599            0.002861            0.002664
# 4            0.002806            0.003090            0.002829
#
#    NON-Strawberry.626  NON-Strawberry.627  NON-Strawberry.628  \
# 0            0.002627            0.002631            0.002730
# 1            0.002629            0.002651            0.002839
# 2            0.002619            0.002696            0.002999
# 3            0.002714            0.002809            0.003259
# 4            0.002939            0.003022            0.003649
#
#    NON-Strawberry.629  NON-Strawberry.630  NON-Strawberry.631
# 0            0.002713            0.002697            0.002789
# 1            0.002779            0.002905            0.003040
# 2            0.002877            0.003277            0.003359
# 3            0.003085            0.003711            0.003796
# 4            0.003419            0.004265            0.004394
#
# [5 rows x 984 columns]

# %% [markdown]
# <br>
# <br>
#
# # Data Wrangling

# %% [markdown]
# ### Isolate Wavenumbers from the dataframe

# %%
# isolate the wavenumbers into a new variable
wavenumbers = df.iloc[:,0]

# %%
# remove "Wavenumbers" from the original df prior to Transposing
df.drop(labels='Wavenumbers', axis=1, inplace=True)

# %% [markdown]
# <br>
#
# ### Transpose the dataframe, and rename the output variable

# %%
# Transpose the df and reset index, then rename the old index
df = df.T
df = df.reset_index()
df = df.rename(columns={'index': 'Outcome'})

# shuffle the df so Outcome is at the end 
df = df.iloc[:,1:].join(df.iloc[:,0])

# %% [markdown]
# <br>
#
# ### Rename the Columns as Wavenumbers

# %%
# convert the wavenumbers to columns and round them down to 3 decimal places
cols = [ round(f, 3) for f in wavenumbers.to_list() ]

# add the final column name 'Outcome' to the list and set the df columns 
cols.append('Outcome')
df.columns = cols

# sort the df by Outcome and reset index
df = df.sort_values('Outcome').reset_index(drop=True)

df
# Out:
#       899.327   903.187   907.047   910.907   914.767   918.627   922.487  \
# 0    0.002806  0.002732  0.002661  0.002657  0.002699  0.002762  0.002749
# 1    0.002637  0.002638  0.002651  0.002757  0.003000  0.003313  0.003412
# 2    0.002054  0.002039  0.002030  0.002076  0.002202  0.002350  0.002408
# 3    0.002330  0.002332  0.002291  0.002328  0.002482  0.002639  0.002655
# 4    0.002562  0.002565  0.002584  0.002691  0.002886  0.003113  0.003233
# ..        ...       ...       ...       ...       ...       ...       ...
# 978  0.002123  0.002187  0.002206  0.002206  0.002351  0.002564  0.002668
# 979  0.002384  0.002392  0.002383  0.002491  0.002710  0.002888  0.002948
# 980  0.002449  0.002499  0.002506  0.002657  0.002912  0.003137  0.003310
# 981  0.002276  0.002358  0.002431  0.002593  0.002830  0.003089  0.003257
# 982  0.002369  0.002374  0.002367  0.002468  0.002628  0.002846  0.002982
#
#       926.347   930.207   934.067  ...  1771.684  1775.544  1779.404  \
# 0    0.002686  0.002637  0.002617  ...  0.000348  0.000216  0.000166
# 1    0.003302  0.003162  0.003060  ...  0.000013  0.000006 -0.000005
# 2    0.002352  0.002276  0.002273  ...  0.000466  0.000294  0.000192
# 3    0.002555  0.002467  0.002428  ...  0.000337  0.000219  0.000111
# 4    0.003239  0.003178  0.003077  ...  0.000307  0.000199  0.000126
# ..        ...       ...       ...  ...       ...       ...       ...
# 978  0.002598  0.002560  0.002507  ...  0.000254  0.000151  0.000096
# 979  0.002914  0.002822  0.002701  ...  0.000103  0.000054  0.000021
# 980  0.003324  0.003217  0.003085  ...  0.000103  0.000057  0.000035
# 981  0.003285  0.003238  0.003143  ...  0.000184  0.000102  0.000060
# 982  0.002963  0.002904  0.002814  ...  0.000143  0.000085  0.000053
#
#      1783.264  1787.124  1790.984  1794.844  1798.704  1802.564  \
# 0    0.000117  0.000087  0.000046  0.000011  0.000009  0.000009
# 1   -0.000005 -0.000006  0.000002  0.000010  0.000005  0.000005
# 2    0.000125  0.000077  0.000054  0.000035  0.000014  0.000014
# 3    0.000071  0.000024  0.000052  0.000061  0.000018  0.000018
# 4    0.000082  0.000051  0.000041  0.000029  0.000009  0.000009
# ..        ...       ...       ...       ...       ...       ...
# 978  0.000066  0.000043  0.000038  0.000037  0.000014  0.000014
# 979  0.000012  0.000005  0.000015  0.000026  0.000013  0.000013
# 980  0.000020  0.000016  0.000015  0.000009  0.000007  0.000007
# 981  0.000032  0.000023  0.000019  0.000014  0.000013  0.000013
# 982  0.000033  0.000024  0.000020  0.000011  0.000005  0.000005
#
#                 Outcome
# 0        NON-Strawberry
# 1      NON-Strawberry.1
# 2     NON-Strawberry.10
# 3    NON-Strawberry.100
# 4    NON-Strawberry.101
# ..                  ...
# 978       Strawberry.95
# 979       Strawberry.96
# 980       Strawberry.97
# 981       Strawberry.98
# 982       Strawberry.99
#
# [983 rows x 236 columns]

# %% [markdown]
# <br>
# <br>
#
# ### Convert the Dependent Variable to True or False values
#
# Binary classification problem

# %%
# replace NON Strawberry outcomes with False
df.loc[:, 'Outcome'] = df.loc[:,'Outcome'].replace(to_replace=r'^NON.*$', value=False, regex=True)

# replace Strawberry with True
df.loc[:, 'Outcome'] = df.loc[:,'Outcome'].replace(to_replace=r'^Straw.*$', value=True, regex=True)

# %%
df
# Out:
#       899.327   903.187   907.047   910.907   914.767   918.627   922.487  \
# 0    0.002806  0.002732  0.002661  0.002657  0.002699  0.002762  0.002749
# 1    0.002637  0.002638  0.002651  0.002757  0.003000  0.003313  0.003412
# 2    0.002054  0.002039  0.002030  0.002076  0.002202  0.002350  0.002408
# 3    0.002330  0.002332  0.002291  0.002328  0.002482  0.002639  0.002655
# 4    0.002562  0.002565  0.002584  0.002691  0.002886  0.003113  0.003233
# ..        ...       ...       ...       ...       ...       ...       ...
# 978  0.002123  0.002187  0.002206  0.002206  0.002351  0.002564  0.002668
# 979  0.002384  0.002392  0.002383  0.002491  0.002710  0.002888  0.002948
# 980  0.002449  0.002499  0.002506  0.002657  0.002912  0.003137  0.003310
# 981  0.002276  0.002358  0.002431  0.002593  0.002830  0.003089  0.003257
# 982  0.002369  0.002374  0.002367  0.002468  0.002628  0.002846  0.002982
#
#       926.347   930.207   934.067  ...  1771.684  1775.544  1779.404  \
# 0    0.002686  0.002637  0.002617  ...  0.000348  0.000216  0.000166
# 1    0.003302  0.003162  0.003060  ...  0.000013  0.000006 -0.000005
# 2    0.002352  0.002276  0.002273  ...  0.000466  0.000294  0.000192
# 3    0.002555  0.002467  0.002428  ...  0.000337  0.000219  0.000111
# 4    0.003239  0.003178  0.003077  ...  0.000307  0.000199  0.000126
# ..        ...       ...       ...  ...       ...       ...       ...
# 978  0.002598  0.002560  0.002507  ...  0.000254  0.000151  0.000096
# 979  0.002914  0.002822  0.002701  ...  0.000103  0.000054  0.000021
# 980  0.003324  0.003217  0.003085  ...  0.000103  0.000057  0.000035
# 981  0.003285  0.003238  0.003143  ...  0.000184  0.000102  0.000060
# 982  0.002963  0.002904  0.002814  ...  0.000143  0.000085  0.000053
#
#      1783.264  1787.124  1790.984  1794.844  1798.704  1802.564  Outcome
# 0    0.000117  0.000087  0.000046  0.000011  0.000009  0.000009    False
# 1   -0.000005 -0.000006  0.000002  0.000010  0.000005  0.000005    False
# 2    0.000125  0.000077  0.000054  0.000035  0.000014  0.000014    False
# 3    0.000071  0.000024  0.000052  0.000061  0.000018  0.000018    False
# 4    0.000082  0.000051  0.000041  0.000029  0.000009  0.000009    False
# ..        ...       ...       ...       ...       ...       ...      ...
# 978  0.000066  0.000043  0.000038  0.000037  0.000014  0.000014     True
# 979  0.000012  0.000005  0.000015  0.000026  0.000013  0.000013     True
# 980  0.000020  0.000016  0.000015  0.000009  0.000007  0.000007     True
# 981  0.000032  0.000023  0.000019  0.000014  0.000013  0.000013     True
# 982  0.000033  0.000024  0.000020  0.000011  0.000005  0.000005     True
#
# [983 rows x 236 columns]

# %% [markdown]
# <br>
# <br>
# <br>
#
# # EDA on the Spectra

# %% [markdown]
# ### Plot wavenumbers for Strawberry == True

# %%
# plot wavenumber vs emission where Strawberry == True
plt.figure(figsize=(15,15))
plt.plot(df.query('Outcome == True').loc[:,df.columns != 'Outcome'].T)
plt.xlabel('Wavenumber');

# %% [markdown]
# <br>
# <br>
#
# ### Plot wavenumbers for Strawberry == False

# %%
# plot the wavenumber vs emission where Strawberry == False
plt.figure(figsize=(12,12))
plt.plot(df.query('Outcome == False').loc[:,df.columns != 'Outcome'].T)
plt.xlabel('Wavenumber');

# %% [markdown]
# <br>
# <br>
#
# ### Split the Data into Training and Validation Sets

# %%
# subset 30% of the dataframe to make up the validation set
dfv = df.sample(frac=0.3, replace=False, random_state=42)

# assign the rest as the training set
dft = df.drop(dfv.index)

# %%
# Shuffle
dft = dft.sample(len(dft)).reset_index(drop=True)
dfv = dfv.sample(len(dfv)).reset_index(drop=True)

# %% [markdown]
# ## Imbalanced!

# %%
dft.Outcome.value_counts()
# Out:
# False    435
# True     253
# Name: Outcome, dtype: int64

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# ### Fix Imbalance with Oversampling

# %%
len(dft)
# Out:
# 688

# %%
f = dft.query('Outcome == False')
t = dft.query('Outcome == True')

# delta = len(f) - len(t)

sam = t.sample(len(f), replace=True)

new = pd.concat([f, sam], ignore_index=True)

dft = new.sample(len(new), replace=False)  # shuffle
dft = dft.reset_index(drop=True)
dft
# Out:
#       899.327   903.187   907.047   910.907   914.767   918.627   922.487  \
# 0    0.002016  0.001992  0.001974  0.001987  0.002036  0.002144  0.002223
# 1    0.003026  0.002967  0.002950  0.003031  0.003222  0.003439  0.003499
# 2    0.002606  0.002723  0.002874  0.003095  0.003407  0.003785  0.004123
# 3    0.002008  0.002067  0.002045  0.002088  0.002288  0.002451  0.002462
# 4    0.002546  0.002538  0.002586  0.002748  0.003032  0.003352  0.003496
# ..        ...       ...       ...       ...       ...       ...       ...
# 865  0.002901  0.002945  0.003005  0.003124  0.003380  0.003688  0.003858
# 866  0.002375  0.002379  0.002380  0.002475  0.002649  0.002810  0.002863
# 867  0.002808  0.002835  0.002885  0.003009  0.003239  0.003478  0.003612
# 868  0.002516  0.002723  0.002938  0.003258  0.003737  0.004339  0.004889
# 869  0.002159  0.002133  0.002067  0.002157  0.002346  0.002512  0.002589
#
#       926.347   930.207   934.067  ...  1771.684  1775.544  1779.404  \
# 0    0.002196  0.002164  0.002154  ...  0.000619  0.000391  0.000247
# 1    0.003374  0.003229  0.003118  ...  0.000019  0.000013  0.000004
# 2    0.004299  0.004256  0.004051  ...  0.000162  0.000105  0.000081
# 3    0.002427  0.002403  0.002437  ...  0.000209  0.000129  0.000074
# 4    0.003453  0.003333  0.003198  ... -0.000026 -0.000035 -0.000034
# ..        ...       ...       ...  ...       ...       ...       ...
# 865  0.003886  0.003808  0.003622  ...  0.000129  0.000083  0.000055
# 866  0.002815  0.002738  0.002664  ...  0.000221  0.000133  0.000085
# 867  0.003642  0.003561  0.003419  ...  0.000241  0.000149  0.000104
# 868  0.005206  0.005185  0.004869  ...  0.000138  0.000079  0.000043
# 869  0.002546  0.002474  0.002444  ...  0.000323  0.000201  0.000132
#
#      1783.264  1787.124  1790.984      1794.844  1798.704  1802.564  Outcome
# 0    0.000160  0.000092  0.000074  5.743610e-05  0.000027  0.000027    False
# 1    0.000003  0.000002  0.000001  5.392030e-07  0.000001  0.000001    False
# 2    0.000055  0.000042  0.000026  9.568990e-06  0.000005  0.000005    False
# 3    0.000045  0.000034  0.000023  5.804170e-06  0.000002  0.000002     True
# 4   -0.000025 -0.000016 -0.000007  2.106660e-06  0.000004  0.000004    False
# ..        ...       ...       ...           ...       ...       ...      ...
# 865  0.000037  0.000023  0.000013  1.529170e-05  0.000011  0.000011     True
# 866  0.000052  0.000030  0.000020  1.143320e-05  0.000005  0.000000    False
# 867  0.000069  0.000049  0.000027  1.252670e-05  0.000009  0.000009     True
# 868  0.000022  0.000010  0.000009  1.158220e-05  0.000007  0.000007    False
# 869  0.000084  0.000053  0.000042  2.532890e-05  0.000007  0.000007    False
#
# [870 rows x 236 columns]

# %% [markdown]
# ### OR Fix Imbalance with Undersampling

# %%
# sam= f.sample(len(t))
# new = pd.concat([t, sam])

# df = new.sample(len(new))  # shuffle
# df = df.reset_index(drop=True)
# df

# %%
dft.Outcome.value_counts()
# Out:
# False    435
# True     435
# Name: Outcome, dtype: int64

# %% [markdown]
# <br>
# <br>
#
# ## ~~Normalize the data~~

# %%
# Find the maximum value of all the independent variables in the Training Set
# maxval = dft.iloc[:, :-1].max().max()  # max of each column , then max of all columns
# maxval

# %%
# Normalize the training set against the maxval and add the output variable back in
# dft_norm = dft.iloc[:, :-1] / maxval
# dft_norm = dft_norm.join(dft.iloc[:, -1])

# dft_norm

# %%
# Normalize the validation set against the maxval and add the output variable back in
# We use the same maxval of the training set to avoid peeking into the future
# dfv_norm = dfv.iloc[:, :-1] / maxval
# dfv_norm = dfv_norm.join(dfv.iloc[:, -1])

# dfv_norm

# %% [markdown]
# <br>
# <br>
#
# ### Plot the Split and Normalized Data

# %% [markdown]
# #### Plot the Training Set where Strawberry == True

# %%
# plot wavenumber vs emission where Strawberry == True
plt.figure(figsize=(12,12))
plt.plot(dft.query('Outcome == True').loc[:,dft.columns != 'Outcome'].T)
plt.xlabel('Wavenumber');

# %% [markdown]
# <br>
#
# #### Plot the Training Set where Strawberry == False

# %%
# plot the wavenumber vs emission where Strawberry == False
plt.figure(figsize=(12,12))
plt.plot(dft.query('Outcome == False').loc[:,dft.columns != 'Outcome'].T)
plt.xlabel('Wavenumber');

# %% [markdown]
# <br>
#
# #### Plot the Validation Set where Strawberry == True

# %%
# plot wavenumber vs emission where Strawberry == True
plt.figure(figsize=(12,12))
plt.plot(dfv.query('Outcome == True').loc[:,dfv.columns != 'Outcome'].T)
plt.xlabel('Wavenumber');

# %% [markdown]
# <br>
#
# #### Plot the Validation Set where Strawberry == False

# %%
# plot the wavenumber vs emission where Strawberry == False
plt.figure(figsize=(12,12))
plt.plot(dfv.query('Outcome == False').loc[:,dfv.columns != 'Outcome'].T)
plt.xlabel('Wavenumber');

# %% [markdown]
# <br>
# <br>
# <br>
#
# ## Preprocessing to make it easier to see errors visually

# %%
dfv.sort_values('Outcome', inplace=True)
dfv
# Out:
#       899.327   903.187   907.047   910.907   914.767   918.627   922.487  \
# 0    0.002723  0.002714  0.002740  0.002861  0.003090  0.003322  0.003428
# 169  0.002318  0.002278  0.002278  0.002349  0.002496  0.002691  0.002727
# 170  0.002018  0.001999  0.001945  0.001964  0.002083  0.002204  0.002225
# 173  0.002630  0.002757  0.002973  0.003304  0.003745  0.004274  0.004764
# 174  0.002421  0.002468  0.002526  0.002646  0.002880  0.003156  0.003300
# ..        ...       ...       ...       ...       ...       ...       ...
# 178  0.002104  0.002094  0.002133  0.002264  0.002494  0.002755  0.002917
# 82   0.002913  0.002946  0.003012  0.003159  0.003413  0.003694  0.003876
# 176  0.002835  0.002819  0.002868  0.002973  0.003177  0.003419  0.003568
# 68   0.002170  0.002195  0.002224  0.002329  0.002529  0.002778  0.002921
# 147  0.002389  0.002363  0.002382  0.002517  0.002766  0.002996  0.003111
#
#       926.347   930.207   934.067  ...  1771.684  1775.544  1779.404  \
# 0    0.003398  0.003266  0.003120  ...  0.000069  0.000033  0.000013
# 169  0.002627  0.002534  0.002483  ...  0.000223  0.000135  0.000085
# 170  0.002175  0.002152  0.002140  ...  0.000603  0.000388  0.000256
# 173  0.005035  0.005003  0.004731  ...  0.000105  0.000061  0.000027
# 174  0.003296  0.003209  0.003071  ...  0.000150  0.000084  0.000053
# ..        ...       ...       ...  ...       ...       ...       ...
# 178  0.002911  0.002823  0.002751  ...  0.000236  0.000143  0.000093
# 82   0.003933  0.003860  0.003684  ...  0.000186  0.000118  0.000105
# 176  0.003593  0.003511  0.003355  ...  0.000212  0.000122  0.000096
# 68   0.002906  0.002840  0.002768  ...  0.000233  0.000144  0.000094
# 147  0.003083  0.002975  0.002878  ...  0.000156  0.000081  0.000052
#
#      1783.264  1787.124  1790.984  1794.844      1798.704      1802.564  \
# 0    0.000007  0.000008  0.000010  0.000015  1.002700e-05  0.000000e+00
# 169  0.000051  0.000035  0.000021  0.000013  7.579850e-06  7.579850e-06
# 170  0.000169  0.000102  0.000064  0.000038  1.465120e-05  1.465120e-05
# 173  0.000014  0.000003 -0.000004 -0.000003 -1.879950e-06 -1.879950e-06
# 174  0.000032  0.000020  0.000013  0.000004  2.412320e-06  0.000000e+00
# ..        ...       ...       ...       ...           ...           ...
# 178  0.000059  0.000040  0.000023  0.000011  6.711650e-06  6.711650e-06
# 82   0.000076  0.000060  0.000016 -0.000011  2.284770e-07  2.284770e-07
# 176  0.000065  0.000054  0.000037  0.000006  6.407270e-06  6.407270e-06
# 68   0.000060  0.000041  0.000021  0.000013  7.690860e-06  7.690860e-06
# 147  0.000031  0.000015  0.000013  0.000010  7.722220e-06  7.722220e-06
#
#      Outcome
# 0      False
# 169    False
# 170    False
# 173    False
# 174    False
# ..       ...
# 178     True
# 82      True
# 176     True
# 68      True
# 147     True
#
# [295 rows x 236 columns]

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
# # Analysis with FastAI

# %% [markdown]
# ### Define the Learner

# %%
from fastai.tabular.all import *

# dls = TabularDataLoaders.from_df(dft, y_names=['Outcome'], procs = [Categorify, FillMissing, Normalize])
dls = TabularDataLoaders.from_df(dft, cont_names=list(dft.columns[:-1]), y_names=['Outcome'])

learn = tabular_learner(dls, lr=1e-3, metrics=[error_rate, accuracy, F1Score(), Precision(), Recall()], 
                        layers=[235,118]) 

#                         layers=[1000,500]) 



#, layers=[1000,10000,10000,10000,1000])

# %%
learn.model
# Out:
# TabularModel(
#   (embeds): ModuleList()
#   (emb_drop): Dropout(p=0.0, inplace=False)
#   (bn_cont): BatchNorm1d(235, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layers): Sequential(
#     (0): LinBnDrop(
#       (0): BatchNorm1d(235, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Linear(in_features=235, out_features=235, bias=False)
#       (2): ReLU(inplace=True)
#     )
#     (1): LinBnDrop(
#       (0): BatchNorm1d(235, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Linear(in_features=235, out_features=118, bias=False)
#       (2): ReLU(inplace=True)
#     )
#     (2): LinBnDrop(
#       (0): Linear(in_features=118, out_features=2, bias=True)
#     )
#   )
# )

# %%
learn.opt_func
# Out:
# <function fastai.optimizer.Adam(params, lr, mom=0.9, sqr_mom=0.99, eps=1e-05, wd=0.01, decouple_wd=True)>

# %% [markdown]
# <br>
# <br>
#
# ### ~~Define an Early Callback~~

# %%
# early_stop = EarlyStoppingCallback(monitor='error_rate', min_delta=0.1, patience=2)

# %% [markdown]
# <br>
# <br>
#
# ## Fit the model

# %%
# plot the learning rates vs loss
lr_min,lr_steep = learn.lr_find()

# %%
print(f"Minimum/10: {lr_min:.2e}, steepest point: {lr_steep:.2e}")
# Out:
# Minimum/10: 2.75e-03, steepest point: 2.51e-03

# %%
# ?learn.fit_one_cycle()
# Out:
# Object `learn.fit_one_cycle()` not found.

# %%
# with learn.no_mbar():
#     learn.fit_one_cycle(35)
learn.fine_tune(100)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.499506</td>
#       <td>0.760641</td>
#       <td>0.522988</td>
#       <td>0.477012</td>
#       <td>0.645914</td>
#       <td>0.477011</td>
#       <td>1.000000</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.239416</td>
#       <td>0.957768</td>
#       <td>0.522988</td>
#       <td>0.477012</td>
#       <td>0.645914</td>
#       <td>0.477011</td>
#       <td>1.000000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.208432</td>
#       <td>1.195833</td>
#       <td>0.522988</td>
#       <td>0.477012</td>
#       <td>0.645914</td>
#       <td>0.477011</td>
#       <td>1.000000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.186597</td>
#       <td>1.391452</td>
#       <td>0.522988</td>
#       <td>0.477012</td>
#       <td>0.645914</td>
#       <td>0.477011</td>
#       <td>1.000000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.166040</td>
#       <td>1.502869</td>
#       <td>0.522988</td>
#       <td>0.477012</td>
#       <td>0.645914</td>
#       <td>0.477011</td>
#       <td>1.000000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.146075</td>
#       <td>1.542363</td>
#       <td>0.522988</td>
#       <td>0.477012</td>
#       <td>0.645914</td>
#       <td>0.477011</td>
#       <td>1.000000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.131659</td>
#       <td>1.351158</td>
#       <td>0.522988</td>
#       <td>0.477012</td>
#       <td>0.645914</td>
#       <td>0.477011</td>
#       <td>1.000000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.118199</td>
#       <td>0.968504</td>
#       <td>0.511494</td>
#       <td>0.488506</td>
#       <td>0.650980</td>
#       <td>0.482558</td>
#       <td>1.000000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.107641</td>
#       <td>0.495691</td>
#       <td>0.264368</td>
#       <td>0.735632</td>
#       <td>0.783019</td>
#       <td>0.643411</td>
#       <td>1.000000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.097233</td>
#       <td>0.180879</td>
#       <td>0.063218</td>
#       <td>0.936782</td>
#       <td>0.937143</td>
#       <td>0.891304</td>
#       <td>0.987952</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.090728</td>
#       <td>0.101234</td>
#       <td>0.051724</td>
#       <td>0.948276</td>
#       <td>0.946108</td>
#       <td>0.940476</td>
#       <td>0.951807</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.083054</td>
#       <td>0.076988</td>
#       <td>0.017241</td>
#       <td>0.982759</td>
#       <td>0.982036</td>
#       <td>0.976190</td>
#       <td>0.987952</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.077152</td>
#       <td>0.094391</td>
#       <td>0.034483</td>
#       <td>0.965517</td>
#       <td>0.963415</td>
#       <td>0.975309</td>
#       <td>0.951807</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.074668</td>
#       <td>0.087150</td>
#       <td>0.028736</td>
#       <td>0.971264</td>
#       <td>0.969697</td>
#       <td>0.975610</td>
#       <td>0.963855</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.073796</td>
#       <td>0.072280</td>
#       <td>0.022989</td>
#       <td>0.977012</td>
#       <td>0.975904</td>
#       <td>0.975904</td>
#       <td>0.975904</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.070757</td>
#       <td>0.099799</td>
#       <td>0.028736</td>
#       <td>0.971264</td>
#       <td>0.969325</td>
#       <td>0.987500</td>
#       <td>0.951807</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.069494</td>
#       <td>0.078816</td>
#       <td>0.017241</td>
#       <td>0.982759</td>
#       <td>0.982036</td>
#       <td>0.976190</td>
#       <td>0.987952</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.062550</td>
#       <td>0.080463</td>
#       <td>0.028736</td>
#       <td>0.971264</td>
#       <td>0.969325</td>
#       <td>0.987500</td>
#       <td>0.951807</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.059780</td>
#       <td>0.089494</td>
#       <td>0.034483</td>
#       <td>0.965517</td>
#       <td>0.963415</td>
#       <td>0.975309</td>
#       <td>0.951807</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.056343</td>
#       <td>0.067082</td>
#       <td>0.028736</td>
#       <td>0.971264</td>
#       <td>0.969697</td>
#       <td>0.975610</td>
#       <td>0.963855</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.052351</td>
#       <td>0.067339</td>
#       <td>0.022989</td>
#       <td>0.977012</td>
#       <td>0.976190</td>
#       <td>0.964706</td>
#       <td>0.987952</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.056765</td>
#       <td>0.089236</td>
#       <td>0.040230</td>
#       <td>0.959770</td>
#       <td>0.957055</td>
#       <td>0.975000</td>
#       <td>0.939759</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.056190</td>
#       <td>0.132839</td>
#       <td>0.045977</td>
#       <td>0.954023</td>
#       <td>0.950617</td>
#       <td>0.974684</td>
#       <td>0.927711</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.055741</td>
#       <td>0.053751</td>
#       <td>0.017241</td>
#       <td>0.982759</td>
#       <td>0.982036</td>
#       <td>0.976190</td>
#       <td>0.987952</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.053580</td>
#       <td>0.070341</td>
#       <td>0.028736</td>
#       <td>0.971264</td>
#       <td>0.969325</td>
#       <td>0.987500</td>
#       <td>0.951807</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.052008</td>
#       <td>0.080620</td>
#       <td>0.028736</td>
#       <td>0.971264</td>
#       <td>0.969697</td>
#       <td>0.975610</td>
#       <td>0.963855</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.054342</td>
#       <td>0.128209</td>
#       <td>0.051724</td>
#       <td>0.948276</td>
#       <td>0.947977</td>
#       <td>0.911111</td>
#       <td>0.987952</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.061373</td>
#       <td>0.085590</td>
#       <td>0.028736</td>
#       <td>0.971264</td>
#       <td>0.969325</td>
#       <td>0.987500</td>
#       <td>0.951807</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.061134</td>
#       <td>0.074750</td>
#       <td>0.034483</td>
#       <td>0.965517</td>
#       <td>0.963415</td>
#       <td>0.975309</td>
#       <td>0.951807</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.059426</td>
#       <td>0.062383</td>
#       <td>0.017241</td>
#       <td>0.982759</td>
#       <td>0.981818</td>
#       <td>0.987805</td>
#       <td>0.975904</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.060474</td>
#       <td>0.064398</td>
#       <td>0.017241</td>
#       <td>0.982759</td>
#       <td>0.982036</td>
#       <td>0.976190</td>
#       <td>0.987952</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.057426</td>
#       <td>0.051183</td>
#       <td>0.017241</td>
#       <td>0.982759</td>
#       <td>0.982036</td>
#       <td>0.976190</td>
#       <td>0.987952</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.052489</td>
#       <td>0.104218</td>
#       <td>0.040230</td>
#       <td>0.959770</td>
#       <td>0.956522</td>
#       <td>0.987179</td>
#       <td>0.927711</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.050447</td>
#       <td>0.051520</td>
#       <td>0.011494</td>
#       <td>0.988506</td>
#       <td>0.987952</td>
#       <td>0.987952</td>
#       <td>0.987952</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.047618</td>
#       <td>0.078620</td>
#       <td>0.028736</td>
#       <td>0.971264</td>
#       <td>0.969325</td>
#       <td>0.987500</td>
#       <td>0.951807</td>
#       <td>00:00</t

# %%
learn.recorder.plot_loss(skip_start=5)

# %% [markdown]
# <br>
# <br>
#
# ### Visualize the Training Set Results

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(figsize=(5,5))

# %% [markdown]
# <br>
# <br>
# <br>
#
# # Show Predictions

# %% [markdown]
# <br>
#
# ### Make a Random Prediction on an Item in the Validation Set

# %%
rown = 3
row = dfv.iloc[rown, :-1]

print(f'Actually a Strawberry:           {dfv.iloc[rown, -1]}')
print(f'Predicted to be a Strawberry:    { bool(learn.predict(row=row)[1]) }')
# print(f'Predicted to be a Strawberry:    { bool(learn.predict(row=row)[-1][1].item()) }')
# Out:
# Actually a Strawberry:           False
# Predicted to be a Strawberry:    False

# %% [markdown]
# <br>
# <br>
# <br>
#
# ## Iteratively Predict Over the Entire Validation Set (Manually)

# %%
TP = 0
TN = 0
FP = 0
FN = 0

print('\n    Showing only Errors\n')
print('idx'.rjust(4) + '    ' + 'Actual'.ljust(6) + '   Predicted' )

for i in range(len(dfv)):
    actual = dfv.iloc[i, -1]
    with learn.no_bar():
        predicted = bool(learn.predict(row=dfv.iloc[i, :-1])[1].item())
    
    if(actual != predicted):
        print(f'{str(i).rjust(4)}    {str(actual).ljust(6)}   {predicted}')
    
    if (predicted == True):
        if (actual == True): TP += 1
        else: FP += 1
            
    if (predicted == False):
        if (actual == False): TN += 1
        else: FN += 1
        
print("\n")
print(f'True Positive={TP}')
print(f'True Negative={TN}')
print(f'False Positive={FP}')
print(f'False Negative={FN}');
# Out:
#     Showing only Errors
#
#  idx    Actual   Predicted
#   42    False    True
#  100    False    True
#  261    True     False
#
#
# True Positive=97
# True Negative=195
# False Positive=2
# False Negative=1

# %% [markdown]
# <br>
# <br>
# <br>
#
# # Score the Predictions (FastAI Version)

# %%
accuracy = (TP + TN) / len(dfv)
precision = TP / (TP + FP)
recall = TP / (TP + FN)
F1 = (2 * precision * recall) / (precision + recall)

print('\nFastAI Predictions: \n')
print(f'Accuracy:    {round(accuracy,4)}')
print(f'Precision:   {round(precision,4)}')
print(f'Recall:      {round(recall,4)}')
print(f'F1 Score:    {round(F1,4)}')
# Out:
# FastAI Predictions:
#
# Accuracy:    0.9898
# Precision:   0.9798
# Recall:      0.9898
# F1 Score:    0.9848

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# # Let's Play with Tensorflow/Keras!
#
# Here we implement a simple backprop network using Keras.

# %%
from sklearn.model_selection import train_test_split
import tensorflow.keras
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Conv1D
from sklearn.preprocessing import MinMaxScaler
from sklearn.utils import class_weight


from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

import warnings
warnings.filterwarnings('ignore')

# %%
# X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size = 0.25)
# dft_orig = dft.copy().astype('float32')
# dfv_orig = dfv.copy().astype('float32')
# dft = dft_orig.copy().astype('float32')
# dfv = dfv_orig.copy().astype('float32')


# scaler_x = MinMaxScaler()
# scaler_y = MinMaxScaler()
# dft = scaler_x.fit_transform(dft)
# dfv = scaler_y.fit_transform(dfv)
# dft = pd.DataFrame(dft, columns=dft_orig.columns)
# dfv = pd.DataFrame(dfv, columns=dfv_orig.columns)

# %%
dft.Outcome = dft.Outcome.replace({1.0:True, 0.0:False})
dfv.Outcome = dfv.Outcome.replace({1.0:True, 0.0:False})
# display(dft, dfv)

# %%
# dft.Outcome = dft.Outcome.replace({True:1, False:0})
# dfv.Outcome = dfv.Outcome.replace({True:1, False:0})

# %%
def create_baseline():
    model = Sequential()


    model.add(Dense(235, input_dim=235, activation='relu', use_bias=True))
#     model.add(tf.keras.layers.BatchNormalization())

    model.add(Dense(118, activation='relu', use_bias=True))
#     model.add(tf.keras.layers.BatchNormalization())


    model.add(Dense(1, activation='sigmoid')) 
    model.build((None, 235))
#     model.summary()
    
#     opt = keras.optimizers.Adam(learning_rate=1e-3, epsilon=1e-5, decay=0.03)
    model.compile('adam', loss='binary_crossentropy', metrics=['accuracy'])

    return model

# %%
len(dfv.columns)
# Out:
# 236

# %%
# epochs_hist = model.fit(dft.iloc[:,:-1].values, dft.iloc[:,-1], epochs=14, batch_size=30,  verbose=1, validation_split=0.3)

X = dft.iloc[:,:-1].values
Y = dft.iloc[:,-1].values

# # encode class values as integers
# encoder = LabelEncoder()
# encoder.fit(Y)
# encoded_Y = encoder.transform(Y)

# epochs_hist = model.fit(X, encoded_Y, epochs=60, batch_size=64,  
#                         use_multiprocessing=True, verbose=1, validation_split=0.25)

# evaluate model with standardized dataset
estimators = []
estimators.append(('standardize', StandardScaler()))
estimators.append(('mlp', KerasClassifier(build_fn=create_baseline, epochs=100, batch_size=5, verbose=0) ))
pipeline = Pipeline(estimators)
# kfold = StratifiedKFold(n_splits=10, shuffle=True)
# results = cross_val_score(pipeline, X, encoded_Y, cv=kfold)
# print("Baseline: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))

# %%
# print(epochs_hist.history.keys())
# estimator.predict(dfv.iloc[6, :-1].astype('float32').values.reshape((1,235)))
pipeline.fit(X, Y)
# Out:
# Pipeline(steps=[('standardize', StandardScaler()),
#                 ('mlp',
#                  <tensorflow.python.keras.wrappers.scikit_learn.KerasClassifier object at 0x7f6763b3c410>)])

# %%
pipeline.predict(dfv.iloc[6, :-1].astype('float32').values.reshape((1,235)))
# Out:
# array([[False]])

# %%
# plt.plot(epochs_hist.history['loss'][3:])
# plt.plot(epochs_hist.history['val_loss'][3:])

# plt.title('Model Loss Progression During Training/Validation')
# plt.ylabel('Training and Validation Losses')
# plt.xlabel('Epoch Number')
# plt.legend(['Training Loss', 'Validation Loss'])

# %%
# model.predict(dfv.iloc[6, :-1].values.reshape((1,235)))
# model.predict(dfv.iloc[6, :-1].astype('float32').values.reshape((1,235)))

# %%
TP = 0
TN = 0
FP = 0
FN = 0

print('\n    Showing only Errors\n')
print('idx'.rjust(4) + '    ' + 'Actual'.ljust(6) + '   Predicted' )

for i in range(len(dfv)):
    actual = bool(dfv.iloc[i, -1])
    predicted = bool(np.round(pipeline.predict(dfv.iloc[i, :-1].astype('float32').values.reshape((1,235))), decimals=0))
    
    if(actual != predicted):
        print(f'{str(i).rjust(4)}    {str(actual).ljust(6)}   {predicted}')
    
    if (predicted == True):
        if (actual == True): TP += 1
        else: FP += 1
            
    if (predicted == False):
        if (actual == False): TN += 1
        else: FN += 1
        
print("\n")
print(f'True Positive={TP}')
print(f'True Negative={TN}')
print(f'False Positive={FP}')
print(f'False Negative={FN}');
# Out:
#     Showing only Errors
#
#  idx    Actual   Predicted
#   70    False    True
#  100    False    True
#  153    False    True
#  197    True     False
#  219    True     False
#  222    True     False
#  261    True     False
#  283    True     False
#
#
# True Positive=93
# True Negative=194
# False Positive=3
# False Negative=5

# %% [markdown]
# <br>
# <br>
# <br>
#
# # Score the Predictions (TensorFlow Version)

# %%
accuracy = (TP + TN) / len(dfv)
precision = TP / (TP + FP)
recall = TP / (TP + FN)
F1 = (2 * precision * recall) / (precision + recall)

print('\nTensorflow Predictions: \n')
print(f'Accuracy:    {round(accuracy,4)}')
print(f'Precision:   {round(precision,4)}')
print(f'Recall:      {round(recall,4)}')
print(f'F1 Score:    {round(F1,4)}')
# Out:
# Tensorflow Predictions:
#
# Accuracy:    0.9729
# Precision:   0.9688
# Recall:      0.949
# F1 Score:    0.9588

# %% [markdown]
# ![image.png](attachment:b6c5d41a-a551-4829-b39e-8f7f9b726e2d.png)
#
# This is a screenshot from the previous analysis with FastAI (earlier in this notebook)
